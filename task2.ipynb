# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import librosa
import librosa.display
import soundfile as sf
import os
import IPython.display as ipd

# %%
def viz(x, sr):
    plt.figure(figsize=(14, 5))
    Xdb = librosa.amplitude_to_db(abs(librosa.stft(x)))
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.show()
    #librosa.feature.mfcc(y=x, sr=sr)
    #librosa.display.specshow(mfccs, sr=sr, x_axis='time')
    #plt.show()
    #chromagram = librosa.feature.chroma_stft(y=x, sr=sr, hop_length=512)
    #librosa.display.specshow(chromagram, x_axis='time', y_axis='chroma', hop_length=512, cmap='coolwarm')
    #plt.show()

audio_filepaths = [os.path.join('files', 'Task_2', f'T2_audio_{i}.wav') for i in 'abcd']
audio_filepaths
# Out:
# ['files\\Task_2\\T2_audio_a.wav',
#  'files\\Task_2\\T2_audio_b.wav',
#  'files\\Task_2\\T2_audio_c.wav',
#  'files\\Task_2\\T2_audio_d.wav']

# %%
x1, sr1 = librosa.load(audio_filepaths[0])
print(x1.shape, sr1)
ipd.Audio(data=x1, rate=sr1)
viz(x1, sr1)
# Out:
# (265129,) 22050

# %%
x2, sr2 = librosa.load(audio_filepaths[1])
print(x2.shape, sr2)
ipd.Audio(data=x2, rate=sr2)
viz(x2, sr2)
# Out:
# (227604,) 22050

# %%
x3, sr3 = librosa.load(audio_filepaths[2])
print(x3.shape, sr3)
ipd.Audio(data=x3, rate=sr3)
viz(x3, sr3)
# Out:
# (290531,) 22050

# %%
x4, sr4 = librosa.load(audio_filepaths[3])
print(x4.shape, sr4)
ipd.Audio(data=x4, rate=sr4)
viz(x4, sr4)
# Out:
# (307995,) 22050
